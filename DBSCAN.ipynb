# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
points=np.array([[3,7],[4,6],[5,5],[6,4],[7,3],[6,2],[7,2],[8,4],[3,3],[2,6],[3,5],[2,4]])

# %%
dbscan = DBSCAN(eps=1.9, min_samples=4)
labels = dbscan.fit_predict(points)

# %%
for label in unique_labels:
  cluster_points=points[labels==label]
  if cluster_points.size==0:
    continue
    if label==-1:
      plt.scatter(cluster_points[:,0],cluster_points[:,1],c='k',marker='x',label='noise')
    else:
       plt.scatter(cluster_points[:,0],cluster_points[:,1],label=f'cluster {label}')

# %%
plt.legend()
plt.title('DBSCAN Clustering Result')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-16-618621421.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
print("clusters label for each point:")
for i,label in enumerate(labels,start =1):
 print(f"p{i}:cluster {label if label !=-1 else'Noise'}")
# Out:
# clusters label for each point:
# p1:cluster 0
# p2:cluster 0
# p3:cluster 0
# p4:cluster 1
# p5:cluster 1
# p6:cluster 1
# p7:cluster 1
# p8:cluster 1
# p9:cluster Noise
# p10:cluster 0
# p11:cluster 0
# p12:cluster 0
